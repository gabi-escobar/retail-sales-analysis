# %%
import pandas as pd
import matplotlib.pyplot as plt
from io import StringIO

# 1. Cargar los Datos
data = """
fecha,ventas
2023-01-01,200
2023-01-02,220
2023-01-03,210
2023-01-04,205
2023-01-05,215
2023-01-06,225
"""

# Cargar los datos en un DataFrame
df = pd.read_csv(StringIO(data))

# 2. Conversión de la Columna 'Fecha'
df['fecha'] = pd.to_datetime(df['fecha'])

# 3. Análisis Descriptivo
print("Estadísticas descriptivas:")
print(df['ventas'].describe())

# 4. Visualización de la Distribución: Histograma y Boxplot

# Histograma de las ventas
plt.figure(figsize=(10, 6))
plt.hist(df['ventas'], bins=5, color='skyblue', edgecolor='black')
plt.title("Distribución de Ventas - Histograma")
plt.xlabel("Ventas")
plt.ylabel("Frecuencia")
plt.grid(axis='y')
plt.show()

# Boxplot de las ventas
plt.figure(figsize=(10, 6))
plt.boxplot(df['ventas'], vert=False, patch_artist=True)
plt.title("Distribución de Ventas - Boxplot")
plt.xlabel("Ventas")
plt.show()

# 5. Gráfico de Líneas para Mostrar Tendencias
plt.figure(figsize=(10, 6))
plt.plot(df['fecha'], df['ventas'], marker='o', linestyle='-', color='blue')
plt.title("Ventas Diarias - Gráfico de Líneas")
plt.xlabel("Fecha")
plt.ylabel("Ventas")
plt.grid(True)
plt.show()

# 6. Gráfico de Dispersión para Analizar Relaciones
plt.figure(figsize=(10, 6))
plt.scatter(df['fecha'], df['ventas'], color='red')
plt.title("Ventas Diarias - Gráfico de Dispersión")
plt.xlabel("Fecha")
plt.ylabel("Ventas")
plt.grid(True)
plt.show()

# 7. Visualización Combinada: Histograma y Boxplot

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Histograma
ax1.hist(df['ventas'], bins=5, color='skyblue', edgecolor='black')
ax1.set_title("Histograma de Ventas")
ax1.set_xlabel("Ventas")
ax1.set_ylabel("Frecuencia")
ax1.grid(axis='y')

# Boxplot
ax2.boxplot(df['ventas'], vert=False, patch_artist=True)
ax2.set_title("Boxplot de Ventas")
ax2.set_xlabel("Ventas")

plt.show()
# Out:
# Estadísticas descriptivas:
# count      6.000000
# mean     212.500000
# std        9.354143
# min      200.000000
# 25%      206.250000
# 50%      212.500000
# 75%      218.750000
# max      225.000000
# Name: ventas, dtype: float64
